# %%
from merge_sort import *

# %%
m = MergeSort()

# %%
items = next(generate_random_numbers(8, 100000))

# %%
import cProfile

exec_code = """
m.merge_sort_single_processed(items)
"""

cProfile.run(exec_code, filename='/tmp/cprof.pstats')

from IPython.display import Image
# !gprof2dot -f pstats /tmp/cprof.pstats | dot -Tpng -o /tmp/output.png
Image(filename='/tmp/output.png')
# Out:
# 'merge_sort_single_processed' 0.81286 sec
